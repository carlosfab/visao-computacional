# %% [markdown]
# # YOLOv9 - O Estado da Arte para Detecção de Objetos
#
# A detecção de objetos é uma tarefa fundamental em visão computacional, e tem visto um progresso extraordinário devido ao avanço dos modelos de *deep learning*.
#
# Nesse escopo de problemas, a família YOLO (*You Only Look Once*) se destaca na vanguarda, reconhecida por sua excepcional velocidade de inferência em tempo real e precisão.
#
# Se você ainda estava absorvendo e testando as aplicações da YOLOv8, eu tenho uma novidade para você. De maneira quase que inesperada, fomos presenteados com a novidade de uma YOLOv9 - possivelmente assumindo a posição de modelo no estado da arte.
#
# <center>
# <img src="https://sigmoidal.ai/wp-content/uploads/2024/02/yolov9-banner.png" width=600>
# </center>
#
#
# ## *YOLOv9: Learning What You Want to Learn Using Programmable Gradient Information - Wang, Chien-Yao  and Liao, Hong-Yuan Mark (2024)*
#
# Abordagens existentes de deep learning em detecção de objetos frequentemente enfatizam o design de arquiteturas de rede complexas ou a elaboração de funções objetivo especializadas. No entanto, elas tendem a negligenciar um problema crucial: os dados sofrem significativa perda de informação durante sua jornada pelas camadas da rede.
#
# Este "gargalo de informação" corrompe os fluxos de gradiente durante a retropropagação, potencialmente levando a atualizações tendenciosas e predições imprecisas do modelo.
#
# <center>
# <img src="https://github.com/carlosfab/yolov9/raw/main/figure/performance.png" width=500></center>
#
# Para enfrentar este desafio, os autores do paper propuseram o conceito de Informação de Gradiente Programável (PGI). PGI introduz um ramo reversível auxiliar que gera gradientes confiáveis, preservando características cruciais de entrada essenciais para a tarefa alvo. Ele evita a diluição semântica que pode ocorrer em técnicas tradicionais de supervisão profunda. Ao efetivamente "programar" o fluxo de informação de gradiente através da rede, PGI facilita resultados de treinamento ideais.
#
# Além disso, os autores também introduziram a Rede de Agregação de Camadas Eficiente Generalizada (GELAN). GELAN equilibra meticulosamente a contagem de parâmetros, complexidade computacional, precisão e velocidade de inferência, oferecendo flexibilidade para implantação em diversos dispositivos. Em um feito notável, GELAN alcança utilização de parâmetros superior em comparação até mesmo com modelos de ponta que dependem de convoluções depth-wise.
#
# **A sinergia de PGI e GELAN forma a espinha dorsal do YOLOv9.** Experimentos exaustivos no dataset MS COCO demonstram o domínio do YOLOv9. Especificamente:
#
# * Desempenho Inigualável: YOLOv9 supera todos os detectores de objetos em tempo real existentes em métricas-chave.
# * Eficiência: Supera até mesmo modelos pré-treinados em grandes conjuntos de dados, enquanto é treinado do zero.
# * Leveza: PGI capacita modelos leves, tornando a detecção de objetos acessível para aplicações cotidianas.
#
#
# Esta aula é apenas uma introdução sobre o modelo YOLOv9. A verdade é que toda a comunidade ainda está estudando o artigo, e validando as informações que têm chegado em um ritmo acelerado.
#
# Se você quer se manter à frente no mercado de Visão Computacional, acompanhe esta primeira introdução que eu preparei para você!

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %% [markdown]
# Para clonar o repositório do YOLOv9 e instalar as dependências necessárias, siga os passos abaixo:

# %%
# Clona o repositório do YOLOv9
# !git clone https://github.com/carlosfab/yolov9.git

# Muda o diretório de trabalho atual para o repositório YOLOv9 clonado
# %cd yolov9

# Instala as dependências necessárias do YOLOv9 a partir do arquivo requirements.txt
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 168 (delta 27), reused 22 (delta 18), pack-reused 127
# Receiving objects: 100% (168/168), 620.20 KiB | 9.40 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# /content/yolov9/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.1 MB/s eta 0:00:00

# %%
# Importa bibliotecas necessárias
import sys
import requests
from tqdm.notebook import tqdm
from pathlib import Path
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams


# Configuração de diretórios para código e dados
CODE_FOLDER = Path("..").resolve()  # Diretório do código
WEIGHTS_FOLDER = CODE_FOLDER / "weights"  # Diretório para pesos do modelo
DATA_FOLDER = CODE_FOLDER / "data"  # Diretório para dados

# Cria os diretórios para pesos e dados, se não existirem
WEIGHTS_FOLDER.mkdir(exist_ok=True, parents=True)
DATA_FOLDER.mkdir(exist_ok=True, parents=True)

# Adiciona o diretório do código ao path do Python para importação de módulos
sys.path.append(str(CODE_FOLDER))

rcParams['figure.figsize'] = 15, 15
# %matplotlib inline

# %%
# URLs dos arquivos de pesos
weight_files = [
    "https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt",
    "https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt",
    "https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt",
    "https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt"
]

# Itera sobre a lista de URLs para baixar os arquivos de pesos
for i, url in enumerate(weight_files, start=1):
    filename = url.split('/')[-1]
    response = requests.get(url, stream=True)
    total_size_in_bytes = int(response.headers.get('content-length', 0))
    block_size = 1024  # 1 Kilobyte
    progress_bar = tqdm(total=total_size_in_bytes, unit='iB', unit_scale=True, desc=f"Baixando arquivo {i}/{len(weight_files)}: {filename}")
    with open(WEIGHTS_FOLDER / filename, 'wb') as file:
        for data in response.iter_content(block_size):
            progress_bar.update(len(data))
            file.write(data)
    progress_bar.close()
# Out:
# Baixando arquivo 1/4: yolov9-c.pt:   0%|          | 0.00/103M [00:00<?, ?iB/s]
# Baixando arquivo 2/4: yolov9-e.pt:   0%|          | 0.00/140M [00:00<?, ?iB/s]
# Baixando arquivo 3/4: gelan-c.pt:   0%|          | 0.00/51.5M [00:00<?, ?iB/s]
# Baixando arquivo 4/4: gelan-e.pt:   0%|          | 0.00/117M [00:00<?, ?iB/s]

# %%
# URL da imagem de teste
url = 'https://sigmoidal.ai/wp-content/uploads/2022/11/314928609_1293071608150779_8666358890956473002_n.jpg'

# Faz a requisição para obter a imagem
response = requests.get(url)

# Define o caminho do arquivo onde a imagem será salva dentro do DATA_FOLDER
image_path = DATA_FOLDER / "test_image.jpg"

# Salva a imagem no diretório especificado
with open(image_path, 'wb') as f:
    f.write(response.content)

# %%
# !python {CODE_FOLDER}/detect.py --weights {WEIGHTS_FOLDER}/yolov9-e.pt --conf 0.1 --source {DATA_FOLDER}/test_image.jpg --device cpu
# Out:
# detect: weights=['/content/yolov9/weights/yolov9-e.pt'], source=/content/yolov9/data/test_image.jpg, data=../data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 26e3791 Python-3.10.12 torch-2.1.0+cu121 CPU
#
# Fusing layers...
# Model summary: 1119 layers, 69470144 parameters, 0 gradients, 244.0 GFLOPs
# image 1/1 /content/yolov9/data/test_image.jpg: 640x608 6 persons, 1 sports ball, 17 bottles, 4 cups, 2 potted plants, 1 dining table, 3 books, 5982.5ms
# Speed: 4.2ms pre-process, 5982.5ms inference, 38.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to ../runs/detect/exp

# %%
# !python {CODE_FOLDER}/detect.py --weights {WEIGHTS_FOLDER}/yolov9-e.pt --conf 0.1 --source {DATA_FOLDER}/rua_1.mp4 --device cpu
# Out:
# detect: weights=['/content/yolov9/weights/yolov9-e.pt'], source=/content/yolov9/data/rua_1.mp4, data=../data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 26e3791 Python-3.10.12 torch-2.1.0+cu121 CPU
#
# Fusing layers...
# Model summary: 1119 layers, 69470144 parameters, 0 gradients, 244.0 GFLOPs
# video 1/1 (1/217) /content/yolov9/data/rua_1.mp4: 384x640 5 persons, 5 cars, 2 trucks, 3883.7ms
# video 1/1 (2/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 1 truck, 3781.6ms
# video 1/1 (3/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 5 cars, 1 truck, 1 traffic light, 4466.1ms
# video 1/1 (4/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 5 cars, 1 truck, 1 stop sign, 3783.4ms
# video 1/1 (5/217) /content/yolov9/data/rua_1.mp4: 384x640 5 persons, 4 cars, 1 truck, 1 traffic light, 3498.1ms
# video 1/1 (6/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 7 cars, 1 truck, 1 stop sign, 5366.3ms
# video 1/1 (7/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 4 cars, 2 trucks, 3873.4ms
# video 1/1 (8/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 5 cars, 1 truck, 3607.2ms
# video 1/1 (9/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 4 cars, 3 trucks, 3854.4ms
# video 1/1 (10/217) /content/yolov9/data/rua_1.mp4: 384x640 4 persons, 4 cars, 2 trucks, 4111.9ms
# video 1/1 (11/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 7 cars, 2 trucks, 1 stop sign, 3626.0ms
# video 1/1 (12/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 9 cars, 1 stop sign, 3676.3ms
# video 1/1 (13/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 1 truck, 4464.8ms
# video 1/1 (14/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 5 cars, 1 motorcycle, 1 truck, 3562.8ms
# video 1/1 (15/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 2 motorcycles, 3670.5ms
# video 1/1 (16/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 1 motorcycle, 4470.9ms
# video 1/1 (17/217) /content/yolov9/data/rua_1.mp4: 384x640 4 persons, 5 cars, 2 trucks, 3541.4ms
# video 1/1 (18/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 6 cars, 1 truck, 2 traffic lights, 3738.6ms
# video 1/1 (19/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 7 cars, 1 truck, 4803.3ms
# video 1/1 (20/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 7 cars, 3734.2ms
# video 1/1 (21/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 7 cars, 2 trucks, 3593.5ms
# video 1/1 (22/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 4477.5ms
# video 1/1 (23/217) /content/yolov9/data/rua_1.mp4: 384x640 6 persons, 7 cars, 3472.1ms
# video 1/1 (24/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 7 cars, 2 trucks, 3604.8ms
# video 1/1 (25/217) /content/yolov9/data/rua_1.mp4: 384x640 5 persons, 6 cars, 3977.6ms
# video 1/1 (26/217) /content/yolov9/data/rua_1.mp4: 384x640 4 persons, 6 cars, 4114.4ms
# video 1/1 (27/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 6 cars, 1 truck, 3577.1ms
# video 1/1 (28/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 7 cars, 1 traffic light, 3592.2ms
# video 1/1 (29/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 7 cars, 1 truck, 1 traffic light, 4485.9ms
# video 1/1 (30/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 6 cars, 2 trucks, 2 traffic lights, 3614.7ms
# video 1/1 (31/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 6 cars, 2 traffic lights, 3745.2ms
# video 1/1 (32/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 5 cars, 1 truck, 1 traffic light, 4476.9ms
# video 1/1 (33/217) /content/yolov9/data/rua_1.mp4: 384x640 4 persons, 6 cars, 2 trucks, 3540.9ms
# video 1/1 (34/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 5 cars, 1 truck, 3800.4ms
# video 1/1 (35/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 1 truck, 1 traffic light, 4481.9ms
# video 1/1 (36/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 7 cars, 1 truck, 3631.8ms
# video 1/1 (37/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 7 cars, 2 trucks, 3743.8ms
# video 1/1 (38/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 7 cars, 4547.0ms
# video 1/1 (39/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 8 cars, 2 trucks, 1 traffic light, 3483.3ms
# video 1/1 (40/217) /content/yolov9/data/rua_1.mp4: 384x640 4 persons, 7 cars, 2 trucks, 3576.9ms
# video 1/1 (41/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 6 cars, 1 truck, 4231.1ms
# video 1/1 (42/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 7 cars, 3731.2ms
# video 1/1 (43/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 1 truck, 3728.8ms
# video 1/1 (44/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 7 cars, 3966.7ms
# video 1/1 (45/217) /content/yolov9/data/rua_1.mp4: 384x640 4 persons, 5 cars, 1 traffic light, 4252.6ms
# video 1/1 (46/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 6 cars, 3690.1ms
# video 1/1 (47/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 5 cars, 1 traffic light, 3639.1ms
# video 1/1 (48/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 4585.0ms
# video 1/1 (49/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 3769.9ms
# video 1/1 (50/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 6 cars, 3564.2ms
# video 1/1 (51/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 6 cars, 1 truck, 4370.2ms
# video 1/1 (52/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 1 traffic light, 3738.0ms
# video 1/1 (53/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 6 cars, 3611.8ms
# video 1/1 (54/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 7 cars, 4379.4ms
# video 1/1 (55/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 5 cars, 1 kite, 3533.5ms
# video 1/1 (56/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 6 cars, 1 truck, 3692.8ms
# video 1/1 (57/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 5 cars, 1 truck, 1 traffic light, 1 stop sign, 4599.1ms
# video 1/1 (58/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 5 cars, 3540.6ms
# video 1/1 (59/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 8 cars, 1 truck, 3633.1ms
# video 1/1 (60/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 7 cars, 4412.3ms
# video 1/1 (61/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 8 cars, 3754.7ms
# video 1/1 (62/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 8 cars, 3614.4ms
# video 1/1 (63/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 7 cars, 3886.9ms
# video 1/1 (64/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 4236.7ms
# video 1/1 (65/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 7 cars, 1 traffic light, 3526.1ms
# video 1/1 (66/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 8 cars, 3461.2ms
# video 1/1 (67/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 4372.8ms
# video 1/1 (68/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 2 trucks, 3714.8ms
# video 1/1 (69/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 8 cars, 3500.6ms
# video 1/1 (70/217) /content/yolov9/data/rua_1.mp4: 384x640 6 cars, 1 truck, 4585.0ms
# video 1/1 (71/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 7 cars, 1 truck, 1 stop sign, 3639.1ms
# video 1/1 (72/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 1 truck, 4704.2ms
# video 1/1 (73/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 1 truck, 4489.1ms
# video 1/1 (74/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 1 truck, 1 traffic light, 3573.1ms
# video 1/1 (75/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 3821.6ms
# video 1/1 (76/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 1 truck, 1 stop sign, 4597.3ms
# video 1/1 (77/217) /content/yolov9/data/rua_1.mp4: 384x640 6 cars, 2 trucks, 1 stop sign, 3576.5ms
# video 1/1 (78/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 6 cars, 4 trucks, 1 potted plant, 3682.2ms
# video 1/1 (79/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 4 cars, 2 trucks, 4455.3ms
# video 1/1 (80/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 4 cars, 3 trucks, 3612.9ms
# video 1/1 (81/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 6 cars, 1 truck, 3585.4ms
# video 1/1 (82/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 6 cars, 1 truck, 1 traffic light, 4401.1ms
# video 1/1 (83/217) /content/yolov9/data/rua_1.mp4: 384x640 6 cars, 1 truck, 3898.1ms
# video 1/1 (84/217) /content/yolov9/data/rua_1.mp4: 384x640 6 cars, 1 truck, 3879.6ms
# video 1/1 (85/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 1 airplane, 1 truck, 4021.0ms
# video 1/1 (86/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 1 truck, 4158.4ms
# video 1/1 (87/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 1 truck, 3574.5ms
# video 1/1 (88/217) /content/yolov9/data/rua_1.mp4: 384x640 6 cars, 1 truck, 1 traffic light, 1 potted plant, 3721.2ms
# video 1/1 (89/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 1 truck, 4551.4ms
# video 1/1 (90/217) /content/yolov9/data/rua_1.mp4: 384x640 5 cars, 1 truck, 3744.6ms
# video 1/1 (91/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 1 traffic light, 1 bench, 3602.9ms
# video 1/1 (92/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 9 cars, 4452.8ms
# video 1/1 (93/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 7 cars, 1 truck, 3568.2ms
# video 1/1 (94/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 9 cars, 3717.1ms
# video 1/1 (95/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 1 truck, 1 stop sign, 4762.5ms
# video 1/1 (96/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 8 cars, 1 truck, 2 stop signs, 3716.5ms
# video 1/1 (97/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 3 trucks, 3811.4ms
# video 1/1 (98/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 9 cars, 2 trucks, 3 traffic lights, 4654.9ms
# video 1/1 (99/217) /content/yolov9/data/rua_1.mp4: 384x640 9 cars, 2 trucks, 3 traffic lights, 3684.8ms
# video 1/1 (100/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 3 trucks, 1 traffic light, 3668.9ms
# video 1/1 (101/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 7 cars, 3 trucks, 1 traffic light, 1 stop sign, 4547.2ms
# video 1/1 (102/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 6 cars, 3 trucks, 1 traffic light, 1 stop sign, 3699.4ms
# video 1/1 (103/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 7 cars, 2 trucks, 3693.9ms
# video 1/1 (104/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 9 cars, 2 trucks, 1 traffic light, 1 stop sign, 4460.3ms
# video 1/1 (105/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 2 trucks, 3 traffic lights, 3737.5ms
# video 1/1 (106/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 1 truck, 3 traffic lights, 3710.9ms
# video 1/1 (107/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 7 cars, 1 truck, 5 traffic lights, 4059.9ms
# video 1/1 (108/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 7 cars, 1 truck, 1 traffic light, 1 stop sign, 4218.7ms
# video 1/1 (109/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 6 cars, 1 truck, 3 traffic lights, 1 stop sign, 3678.0ms
# video 1/1 (110/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 1 truck, 2 traffic lights, 3552.1ms
# video 1/1 (111/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 8 cars, 1 truck, 3 traffic lights, 1 stop sign, 4586.0ms
# video 1/1 (112/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 7 cars, 1 truck, 2 traffic lights, 2 stop signs, 3659.6ms
# video 1/1 (113/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 7 cars, 1 truck, 2 traffic lights, 2 stop signs, 3543.5ms
# video 1/1 (114/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 1 truck, 3 traffic lights, 1 stop sign, 1 bird, 4407.4ms
# video 1/1 (115/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 8 cars, 1 truck, 2 traffic lights, 2 stop signs, 3642.5ms
# video 1/1 (116/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 1 traffic light, 1 stop sign, 3706.6ms
# video 1/1 (117/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 2 traffic lights, 4484.7ms
# video 1/1 (118/217) /content/yolov9/data/rua_1.mp4: 384x640 7 cars, 1 truck, 2 traffic lights, 1 fire hydrant, 3677.9ms
# video 1/1 (119/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 7 cars, 3 traffic lights, 1 fire hydrant, 3682.9ms
# video 1/1 (120/217) /content/yolov9/data/rua_1.mp4: 384x640 8 cars, 2 traffic lights, 1 bench, 4468.2ms
# video 1/1 (121/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 9 cars, 3 traffic lights, 1 stop sign, 1 bird, 3534.5ms
# video 1/1 (122/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 6 cars, 1 stop sign, 3761.9ms
# video 1/1 (123/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 6 cars, 1 traffic light, 4493.3ms
# video 1/1 (124/217) /content/yolov9/data/rua_1.mp4: 384x640 4 persons, 6 cars, 1 traffic light, 1 stop sign, 3637.5ms
# video 1/1 (125/217) /content/yolov9/data/rua_1.mp4: 384x640 1 bicycle, 7 cars, 1 stop sign, 3517.6ms
# video 1/1 (126/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 6 cars, 1 stop sign, 3752.7ms
# video 1/1 (127/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 1 bicycle, 6 cars, 1 stop sign, 4200.4ms
# video 1/1 (128/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 1 bicycle, 7 cars, 1 bus, 1 stop sign, 3674.6ms
# video 1/1 (129/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 1 stop sign, 3650.9ms
# video 1/1 (130/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 6 cars, 1 stop sign, 4364.8ms
# video 1/1 (131/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 6 cars, 1 stop sign, 3778.6ms
# video 1/1 (132/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 1 bicycle, 5 cars, 1 stop sign, 3603.7ms
# video 1/1 (133/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 6 cars, 1 truck, 1 stop sign, 1 bench, 4496.0ms
# video 1/1 (134/217) /content/yolov9/data/rua_1.mp4: 384x640 1 bicycle, 6 cars, 1 stop sign, 3667.9ms
# video 1/1 (135/217) /content/yolov9/data/rua_1.mp4: 384x640 1 bicycle, 6 cars, 1 stop sign, 3463.3ms
# video 1/1 (136/217) /content/yolov9/data/rua_1.mp4: 384x640 4 persons, 1 bicycle, 5 cars, 1 stop sign, 4414.5ms
# video 1/1 (137/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 1 bicycle, 5 cars, 1 stop sign, 4438.2ms
# video 1/1 (138/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 1 bicycle, 6 cars, 3592.5ms
# video 1/1 (139/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 9 cars, 1 truck, 1 bench, 1 bird, 4457.0ms
# video 1/1 (140/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 9 cars, 1 truck, 2 traffic lights, 3687.8ms
# video 1/1 (141/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 9 cars, 1 traffic light, 1 bench, 3623.3ms
# video 1/1 (142/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 7 cars, 4562.2ms
# video 1/1 (143/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 1 bicycle, 6 cars, 1 traffic light, 1 stop sign, 3683.5ms
# video 1/1 (144/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 8 cars, 1 traffic light, 3580.7ms
# video 1/1 (145/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 9 cars, 1 truck, 1 traffic light, 4182.8ms
# video 1/1 (146/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 1 bicycle, 6 cars, 2 trucks, 1 potted plant, 3825.3ms
# video 1/1 (147/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 8 cars, 1 truck, 1 stop sign, 3479.0ms
# video 1/1 (148/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 7 cars, 1 truck, 1 bench, 3877.8ms
# video 1/1 (149/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 8 cars, 2 trucks, 1 traffic light, 1 stop sign, 1 potted plant, 4361.9ms
# video 1/1 (150/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 9 cars, 2 trucks, 1 traffic light, 1 potted plant, 3716.0ms
# video 1/1 (151/217) /content/yolov9/data/rua_1.mp4: 384x640 1 bicycle, 8 cars, 2 trucks, 2 traffic lights, 2 stop signs, 3769.5ms
# video 1/1 (152/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 8 cars, 2 trucks, 1 traffic light, 1 stop sign, 4416.9ms
# video 1/1 (153/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 9 cars, 1 truck, 3576.5ms
# video 1/1 (154/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 8 cars, 1 traffic light, 3593.7ms
# video 1/1 (155/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 1 bicycle, 8 cars, 1 truck, 2 traffic lights, 4455.3ms
# video 1/1 (156/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 12 cars, 2 traffic lights, 3587.8ms
# video 1/1 (157/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 2 traffic lights, 1 potted plant, 3689.1ms
# video 1/1 (158/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 1 traffic light, 1 stop sign, 4467.9ms
# video 1/1 (159/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 1 bicycle, 8 cars, 2 trucks, 2 traffic lights, 1 stop sign, 3472.2ms
# video 1/1 (160/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 1 bicycle, 11 cars, 1 truck, 1 traffic light, 1 stop sign, 3623.6ms
# video 1/1 (161/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 9 cars, 1 truck, 1 traffic light, 2 stop signs, 4096.7ms
# video 1/1 (162/217) /content/yolov9/data/rua_1.mp4: 384x640 12 cars, 3 trucks, 2 stop signs, 3777.8ms
# video 1/1 (163/217) /content/yolov9/data/rua_1.mp4: 384x640 11 cars, 1 bus, 4 trucks, 1 stop sign, 3649.9ms
# video 1/1 (164/217) /content/yolov9/data/rua_1.mp4: 384x640 10 cars, 2 trucks, 2 stop signs, 3936.9ms
# video 1/1 (165/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 11 cars, 1 truck, 2 stop signs, 4237.2ms
# video 1/1 (166/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 12 cars, 2 trucks, 1 stop sign, 3551.4ms
# video 1/1 (167/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 10 cars, 1 truck, 1 traffic light, 3 stop signs, 3539.2ms
# video 1/1 (168/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 10 cars, 1 truck, 3 stop signs, 4557.4ms
# video 1/1 (169/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 11 cars, 2 trucks, 1 stop sign, 3762.8ms
# video 1/1 (170/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 11 cars, 2 trucks, 1 stop sign, 3708.3ms
# video 1/1 (171/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 13 cars, 2 trucks, 4 stop signs, 4508.5ms
# video 1/1 (172/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 11 cars, 1 truck, 2 stop signs, 3582.4ms
# video 1/1 (173/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 12 cars, 2 stop signs, 3604.7ms
# video 1/1 (174/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 11 cars, 1 truck, 4409.3ms
# video 1/1 (175/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 10 cars, 1 truck, 1 stop sign, 3498.3ms
# video 1/1 (176/217) /content/yolov9/data/rua_1.mp4: 384x640 13 cars, 1 truck, 2 traffic lights, 1 stop sign, 3605.0ms
# video 1/1 (177/217) /content/yolov9/data/rua_1.mp4: 384x640 14 cars, 1 stop sign, 4432.7ms
# video 1/1 (178/217) /content/yolov9/data/rua_1.mp4: 384x640 9 cars, 2 trucks, 1 traffic light, 1 stop sign, 3683.5ms
# video 1/1 (179/217) /content/yolov9/data/rua_1.mp4: 384x640 10 cars, 2 trucks, 1 traffic light, 1 stop sign, 3613.8ms
# video 1/1 (180/217) /content/yolov9/data/rua_1.mp4: 384x640 10 cars, 2 trucks, 1 traffic light, 1 stop sign, 3830.1ms
# video 1/1 (181/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 10 cars, 2 trucks, 1 traffic light, 1 stop sign, 4148.6ms
# video 1/1 (182/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 10 cars, 1 traffic light, 1 stop sign, 3664.2ms
# video 1/1 (183/217) /content/yolov9/data/rua_1.mp4: 384x640 10 cars, 1 traffic light, 1 stop sign, 3753.1ms
# video 1/1 (184/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 9 cars, 2 traffic lights, 1 stop sign, 4382.6ms
# video 1/1 (185/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 12 cars, 1 traffic light, 1 stop sign, 3 refrigerators, 3677.4ms
# video 1/1 (186/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 12 cars, 1 truck, 1 stop sign, 3662.6ms
# video 1/1 (187/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 11 cars, 1 traffic light, 5 refrigerators, 4528.1ms
# video 1/1 (188/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 11 cars, 1 motorcycle, 1 truck, 1 bench, 3715.2ms
# video 1/1 (189/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 13 cars, 1 traffic light, 1 bench, 3599.5ms
# video 1/1 (190/217) /content/yolov9/data/rua_1.mp4: 384x640 1 bicycle, 13 cars, 1 stop sign, 4459.5ms
# video 1/1 (191/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 12 cars, 1 traffic light, 1 bench, 3731.1ms
# video 1/1 (192/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 11 cars, 1 traffic light, 1 bench, 3500.2ms
# video 1/1 (193/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 14 cars, 1 traffic light, 1 bench, 4478.8ms
# video 1/1 (194/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 13 cars, 1 traffic light, 1 bench, 3720.4ms
# video 1/1 (195/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 11 cars, 2 trucks, 1 traffic light, 1 backpack, 3632.7ms
# video 1/1 (196/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 12 cars, 1 stop sign, 1 bench, 2 handbags, 4467.3ms
# video 1/1 (197/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 12 cars, 2 traffic lights, 1 stop sign, 1 bench, 1 backpack, 3892.2ms
# video 1/1 (198/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 13 cars, 1 truck, 1 traffic light, 1 stop sign, 1 bench, 3682.8ms
# video 1/1 (199/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 12 cars, 2 trucks, 1 traffic light, 1 stop sign, 1 bench, 4246.1ms
# video 1/1 (200/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 11 cars, 2 trucks, 1 stop sign, 1 bench, 1 frisbee, 4030.7ms
# video 1/1 (201/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 15 cars, 1 truck, 2 stop signs, 1 bench, 3547.2ms
# video 1/1 (202/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 14 cars, 2 traffic lights, 1 stop sign, 1 bench, 4524.7ms
# video 1/1 (203/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 13 cars, 3 traffic lights, 1 stop sign, 1 bench, 4853.9ms
# video 1/1 (204/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 15 cars, 3 trucks, 1 traffic light, 1 bench, 1 handbag, 3650.2ms
# video 1/1 (205/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 10 cars, 3 trucks, 1 stop sign, 1 bench, 3550.1ms
# video 1/1 (206/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 11 cars, 2 trucks, 1 traffic light, 1 bench, 4406.4ms
# video 1/1 (207/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 12 cars, 2 trucks, 3 traffic lights, 3668.2ms
# video 1/1 (208/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 10 cars, 3 trucks, 2 stop signs, 3892.7ms
# video 1/1 (209/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 12 cars, 3 trucks, 1 traffic light, 4448.7ms
# video 1/1 (210/217) /content/yolov9/data/rua_1.mp4: 384x640 1 person, 9 cars, 2 trucks, 2 traffic lights, 1 stop sign, 3635.8ms
# video 1/1 (211/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 10 cars, 1 motorcycle, 3 trucks, 1 traffic light, 3496.9ms
# video 1/1 (212/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 11 cars, 1 truck, 1 traffic light, 1 stop sign, 4582.5ms
# video 1/1 (213/217) /content/yolov9/data/rua_1.mp4: 384x640 4 persons, 11 cars, 2 trucks, 1 stop sign, 3675.2ms
# video 1/1 (214/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 15 cars, 1 motorcycle, 1 truck, 2 stop signs, 3521.7ms
# video 1/1 (215/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 13 cars, 1 truck, 3 traffic lights, 1 stop sign, 4088.0ms
# video 1/1 (216/217) /content/yolov9/data/rua_1.mp4: 384x640 2 persons, 13 cars, 3 trucks, 3 traffic lights, 1 stop sign, 3942.8ms
# video 1/1 (217/217) /content/yolov9/data/rua_1.mp4: 384x640 3 persons, 13 cars, 1 truck, 3 traffic lights, 1 stop sign, 3739.7ms
# Speed: 1.2ms pre-process, 3928.3ms inference, 11.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to ../runs/detect/exp2
