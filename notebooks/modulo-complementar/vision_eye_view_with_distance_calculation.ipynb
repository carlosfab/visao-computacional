# %%
import cv2
import math
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

model = YOLO("yolov8s.pt")
cap = cv2.VideoCapture("./IMG_1075.MOV")

w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

out = cv2.VideoWriter('visioneye-distance-calculation.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))

center_point = (0, h)
pixel_per_meter = 10

txt_color, txt_background, bbox_clr = ((0, 0, 0), (255, 255, 255), (255, 0, 255))

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    annotator = Annotator(im0, line_width=2)

    results = model.track(im0, persist=True)
    boxes = results[0].boxes.xyxy.cpu()

    if results[0].boxes.id is not None:
        track_ids = results[0].boxes.id.int().cpu().tolist()

        for box, track_id in zip(boxes, track_ids):
            annotator.box_label(box, label=str(track_id), color=bbox_clr)
            annotator.visioneye(box, center_point)

            x1, y1 = int((box[0] + box[2]) // 2), int((box[1] + box[3]) // 2)    # Bounding box centroid

            distance = (math.sqrt((x1 - center_point[0]) ** 2 + (y1 - center_point[1]) ** 2))/pixel_per_meter

            text_size, _ = cv2.getTextSize(f"Distance: {distance:.2f} m", cv2.FONT_HERSHEY_SIMPLEX,1.2, 3)
            cv2.rectangle(im0, (x1, y1 - text_size[1] - 10),(x1 + text_size[0] + 10, y1), txt_background, -1)
            cv2.putText(im0, f"Distance: {distance:.2f} m",(x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 1.2,txt_color, 3)

    out.write(im0)
    cv2.imshow("visioneye-distance-calculation", im0)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at '/Users/carlos/Library/Application Support/Ultralytics/settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8s.pt to 'yolov8s.pt'...
# 100%|██████████| 21.5M/21.5M [00:05<00:00, 3.87MB/s]
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Collecting lapx>=0.5.2
#   Downloading lapx-0.5.5-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.6 kB)
# Collecting Cython>=0.29.32 (from lapx>=0.5.2)
#   Downloading Cython-3.0.9-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.21.6 in /Users/carlos/Projects/visao-computacional/.venv/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.1)
# Downloading lapx-0.5.5-cp311-cp311-macosx_10_9_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 1.7 MB/s eta 0:00:00a 0:00:01
# Downloading Cython-3.0.9-cp311-cp311-macosx_10_9_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 2.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: Cython, lapx
# Successfully installed Cython-3.0.9 lapx-0.5.5
#
# requirements: AutoUpdate success ✅ 7.1s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# 0: 640x384 2 persons, 109.4ms
# Speed: 7.0ms preprocess, 109.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 109.9ms
# Speed: 2.4ms preprocess, 109.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 90.1ms
# Speed: 2.1ms preprocess, 90.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 90.4ms
# Speed: 1.9ms preprocess, 90.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 93.0ms
# Speed: 2.3ms preprocess, 93.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 86.6ms
# Speed: 2.1ms preprocess, 86.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 82.9ms
# Speed: 1.6ms preprocess, 82.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 88.7ms
# Speed: 1.7ms preprocess, 88.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 90.0ms
# Speed: 2.8ms preprocess, 90.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 92.4ms
# Speed: 2.0ms preprocess, 92.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 89.6ms
# Speed: 2.7ms preprocess, 89.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 fire hydrant, 80.0ms
# Speed: 3.6ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 96.8ms
# Speed: 2.2ms preprocess, 96.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 fire hydrant, 99.4ms
# Speed: 2.6ms preprocess, 99.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 91.8ms
# Speed: 1.7ms preprocess, 91.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 88.9ms
# Speed: 2.0ms preprocess, 88.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 120.1ms
# Speed: 1.7ms preprocess, 120.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 153.4ms
# Speed: 1.9ms preprocess, 153.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 133.6ms
# Speed: 3.5ms preprocess, 133.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 136.1ms
# Speed: 2.4ms preprocess, 136.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 144.1ms
# Speed: 4.8ms preprocess, 144.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car,
6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 97.5ms
# Speed: 3.3ms preprocess, 97.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 88.2ms
# Speed: 1.9ms preprocess, 88.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 108.1ms
# Speed: 3.3ms preprocess, 108.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 88.0ms
# Speed: 3.8ms preprocess, 88.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 108.7ms
# Speed: 3.9ms preprocess, 108.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 104.6ms
# Speed: 4.3ms preprocess, 104.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 133.7ms
# Speed: 2.8ms preprocess, 133.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 118.7ms
# Speed: 3.8ms preprocess, 118.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 133.2ms
# Speed: 1.7ms preprocess, 133.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 121.2ms
# Speed: 1.6ms preprocess, 121.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 101.9ms
# Speed: 3.4ms preprocess, 101.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 99.5ms
# Speed: 4.2ms preprocess, 99.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 108.3ms
# Speed: 1.7ms preprocess, 108.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 92.0ms
# Speed: 3.9ms preprocess, 92.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 115.1ms
# Speed: 1.9ms preprocess, 115.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 128.2ms
# Speed: 2.7ms preprocess, 128.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 96.2ms
# Speed: 1.9ms preprocess, 96.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 114.0ms
# Speed: 3.3ms preprocess, 114.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 129.6ms
# Speed: 3.4ms preprocess, 129.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 114.9ms
# Speed: 3.0ms preprocess, 114.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 138.9ms
# Speed: 2.5ms preprocess, 138.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 136.7ms
# Speed: 2.5ms preprocess, 136.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 114.8ms
# Speed: 2.0ms preprocess, 114.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 105.8ms
# Speed: 3.4ms preprocess, 105.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 138.9ms
# Speed: 2.2ms preprocess, 138.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 103.6ms
# Speed: 3.0ms preprocess, 103.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 135.3ms
# Speed: 1.9ms preprocess, 135.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 114.1ms
# Speed: 3.2ms preprocess, 114.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 117.8ms
# Speed: 2.0ms preprocess, 117.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 110.4ms
# Speed: 3.9ms preprocess, 110.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 101.7ms
# Speed: 2.9ms preprocess, 101.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 car, 1 fire hydrant, 105.5ms
# Speed: 1.8ms preprocess, 105.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 87.2ms
# Speed: 1.8ms preprocess, 87.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 skateboard, 98.6ms
# Speed: 3.2ms preprocess, 98.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 fire hydrant, 104.9ms
# Speed: 2.1ms preprocess, 104.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 fire hydrant, 94.5ms
# Speed: 1.7ms preprocess, 94.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 fire hydrant, 100.2ms
# Speed: 1.7ms preprocess, 100.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 fire hydrant, 100.7ms
# Speed: 1.7ms preprocess, 100.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 fire hydrant, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 89.0ms
# Speed: 1.6ms preprocess, 89.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 132.3ms
# Speed: 3.9ms preprocess, 132.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 131.3ms
# Speed: 1.7ms preprocess, 131.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 106.5ms
# Speed: 1.6ms preprocess, 106.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 135.5ms
# Speed: 3.6ms preprocess, 135.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 bench, 86.5ms
# Speed: 1.8ms preprocess, 86.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 bench, 98.7ms
# Speed: 3.2ms preprocess, 98.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 88.6ms
# Speed: 1.6ms preprocess, 88.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 90.9ms
# Speed: 1.7ms preprocess, 90.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 96.1ms
# Speed: 5.4ms preprocess, 96.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 117.6ms
# Speed: 1.5ms preprocess, 117.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 113.5ms
# Speed: 3.4ms preprocess, 113.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 skateboard, 115.9ms
# Speed: 2.1ms preprocess, 115.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 handbag, 89.7ms
# Speed: 1.6ms preprocess, 89.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 dog, 106.0ms
# Speed: 3.8ms preprocess, 106.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 106.5ms
# Speed: 1.6ms preprocess, 106.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 87.2ms
# Speed: 1.6ms preprocess, 87.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 90.2ms
# Speed: 2.2ms preprocess, 90.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 93.1ms
# Speed: 1.7ms preprocess, 93.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 99.5ms
# Speed: 1.6ms preprocess, 99.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 136.6ms
# Speed: 5.4ms preprocess, 136.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 106.5ms
# Speed: 2.2ms preprocess, 106.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 96.0ms
# Speed: 1.6ms preprocess, 96.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 119.1ms
# Speed: 3.8ms preprocess, 119.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 133.5ms
# Speed: 1.7ms preprocess, 133.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 147.0ms
# Speed: 3.5ms preprocess, 147.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 99.7ms
# Speed: 1.9ms preprocess, 99.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 98.0ms
# Speed: 5.1ms preprocess, 98.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 98.9ms
# Speed: 1.7ms preprocess, 98.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 88.3ms
# Speed: 2.6ms preprocess, 88.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 96.2ms
# Speed: 1.5ms preprocess, 96.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 100.9ms
# Speed: 1.7ms preprocess, 100.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 93.9ms
# Speed: 1.7ms preprocess, 93.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 116.6ms
# Speed: 2.2ms preprocess, 116.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 100.2ms
# Speed: 1.6ms preprocess, 100.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 120.5ms
# Speed: 1.6ms preprocess, 120.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 134.1ms
# Speed: 1.7ms preprocess, 134.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 103.7ms
# Speed: 4.2ms preprocess, 103.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 109.3ms
# Speed: 3.9ms preprocess, 109.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 102.7ms
# Speed: 3.5ms preprocess, 102.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 137.1ms
# Speed: 3.3ms preprocess, 137.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 98.3ms
# Speed: 3.7ms preprocess, 98.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 109.7ms
# Speed: 3.1ms preprocess, 109.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 116.6ms
# Speed: 3.3ms preprocess, 116.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 106.9ms
# Speed: 1.7ms preprocess, 106.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 106.4ms
# Speed: 2.0ms preprocess, 106.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 114.2ms
# Speed: 2.3ms preprocess, 114.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 129.5ms
# Speed: 2.0ms preprocess, 129.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 125.0ms
# Speed: 5.3ms preprocess, 125.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 handbag, 111.6ms
# Speed: 1.5ms preprocess, 111.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 108.1ms
# Speed: 3.6ms preprocess, 108.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 109.7ms
# Speed: 1.9ms preprocess, 109.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 117.7ms
# Speed: 2.3ms preprocess, 117.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 91.7ms
# Speed: 3.9ms preprocess, 91.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 94.9ms
# Speed: 2.4ms preprocess, 94.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 96.4ms
# Speed: 2.2ms preprocess, 96.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 90.0ms
# Speed: 1.6ms preprocess, 90.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 87.7ms
# Speed: 3.6ms preprocess, 87.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 105.3ms
# Speed: 2.0ms preprocess, 105.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 100.9ms
# Speed: 3.5ms preprocess, 100.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 101.4ms
# Speed: 1.6ms preprocess, 101.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 92.9ms
# Speed: 1.6ms preprocess, 92.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 110.8ms
# Speed: 2.2ms preprocess, 110.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 97.8ms
# Speed: 3.2ms preprocess, 97.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 103.8ms
# Speed: 1.7ms preprocess, 103.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 85.4ms
# Speed: 2.4ms preprocess, 85.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 97.4ms
# Speed: 1.9ms preprocess, 97.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 98.3ms
# Speed: 1.6ms preprocess, 98.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 92.7ms
# Speed: 1.8ms preprocess, 92.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 1 skateboard, 93.2ms
# Speed: 2.4ms preprocess, 93.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 116.9ms
# Speed: 3.4ms preprocess, 116.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 95.7ms
# Speed: 1.6ms preprocess, 95.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 101.8ms
# Speed: 2.0ms preprocess, 101.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 108.0ms
# Speed: 1.6ms preprocess, 108.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 99.3ms
# Speed: 3.7ms preprocess, 99.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 99.0ms
# Speed: 2.0ms preprocess, 99.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 103.0ms
# Speed: 2.1ms preprocess, 103.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 99.7ms
# Speed: 2.2ms preprocess, 99.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 109.2ms
# Speed: 3.3ms preprocess, 109.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Video frame is empty or video processing has been successfully completed.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
